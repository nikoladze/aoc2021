# %%
from solver import parse, VentMap
import matplotlib.pyplot as plt

# %%
data = parse(open("input.txt").read())

# %%
vent_map = VentMap(data, consider_diagonals=True)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(vent_map.map, cmap="turbo")
